# %% [markdown]
# <a href="https://colab.research.google.com/github/DianaKahar/Data_management/blob/main/P137263_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ASSIGNMENT 1**

# %%
# !git config --global user.name "DianaKahar"
# !git config --global user.email "dianabdkahar@gmail.com"

# %%
token = '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'
username = 'DianaKahar'
repo = 'Data_Management'

# %%
# !git clone https://{token}@github.com/{username}//{repo}
# Out:
# Cloning into 'Data_Management'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 1), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (12/12), 480.26 KiB | 6.76 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd {repo}
# Out:
# /content/Data_Management

# %%
# %ls
# Out:
# healthcare_dataset.csv  P137263_Assignment1.ipynb  README.md

# %%
# !pwd
# Out:
# /content/Data_Management

# %%
# !git add .

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/Data_Management/.git/

# %%
# !git add P137263_Assignment1.ipynb
# !git commit -m 'commit message'
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %% [markdown]
# # **STQD6324 DATA MANAGEMENT**

# %% [markdown]
# **INTRODUCTION**

# %% [markdown]
# Healthcare is one of the major industries of progress and innovation, improving on all aspects like patient care, operational efficiency and advancing medical research. The collection and analysis of data, also efficient management plays a vital role in enhancing and transforming healthcare outcomes.
#
# Enormous amounts of data is generated daily by healthcare institutions, from medical imaging, genomic sequence, EHR (encompassing electronic health records), administration records and many more. The vast collection of data helps analyze valuable insights into a patient's demographic, disease widespread, treatment productiveness and resource utilization. Data management strategies and analytic techniques enable an organization to utilize the full potential of data collected.
#
# Healthcare data management requires the collection, storing, organizing and analyzing various datasets to assist in clinical decision making, optimization or operations and strategic planning. Healthcare providers are able to extract important insight from raw data which enables them to deliver specialized patient care, pinpoint high risk populations and  streamline healthcare workflows with the utilization of advanced analytics like machine learning algorithms and artificial intelligence tools.
#
# In addition, data management institutes are able to centralize the data that helps  practice collaborations, sharing knowledge among researchers, healthcare professionals and policymakers which accelerates scientific discoveries and enhances healthcare services and outcomes. The data collected from historical patient data aids healthcare providers to recognize patterns, predict disease progression and intervene early to prevent adverse outcomes. Real time data analytics assist healthcare professionals in personalizing treatments plans for patients needs, monitor patient responses which leads to a better patient quality care.
#
# For assignment 1, with the healthcare dataset required several analyses will be performed to gain insight and understand some underlying patterns.
#
# 1. Statistical summary for age and billing amount and determining the distribution of catagorical variable like blood type, gender and medical condition.

# %% [markdown]
# **DATASET INFORMATION**

# %% [markdown]
# For this assignment, the healthcare dataset was obtained from Kaggle.com, titled "Healthcare Dataset". The dataset contains 15 variables/columns which provides specific information on the patient, their admission and healthcare service provided.
#
# 1. Name: Patients name.
# 2. Age: Patients age.
# 3. Gender: "Male" or "Female."
# 4. Blood Type: The patient's blood type. (A, B, AB, O / POSITIVE OR NEGATIVE).
# 5. Medical Condition: Primary medical condition.
# 6. Date of Admission: Patient admission date.
# 7. Doctor: Doctors name for patient.
# 8. Hospital: Name of healthcare location.
# 9. Insurance Provider: Patient's insurance provider
# 10. Billing Amount: Billed expenses (USD).
# 11. Room Number: Room number at hospital.
# 12. Admission Type: Specifies the type of admission ("Emergency," "Elective," or "Urgent,").
# 13. Discharge Date: Discharged date.
# 14. Medication: Medication prescribed.
# 15. Test Results: Results of a medical test ("Normal," "Abnormal," or "Inconclusive,").

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Data_Management/healthcare_dataset.csv")
df.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# ...

# %% [markdown]
# **DATA CLEANING AND EXPLORATION**

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
summary_stats = df[['Age', 'Billing Amount']].describe()
print(summary_stats)
# Out:
#                 Age  Billing Amount
# count  10000.000000    10000.000000
# mean      51.452200    25516.806778
# std       19.588974    14067.292709
# min       18.000000     1000.180837
# 25%       35.000000    13506.523967
# 50%       52.000000    25258.112566
# 75%       68.000000    37733.913727
# max       85.000000    49995.902283

# %% [markdown]
# From the dataframe the summary stats were calculated for the variables 'Age' and 'Billing amount' only to understand the mean, std, min and max for patients within the healthcare dataset. From the variable 'Age' we are able to see that the minimum age of a patient is starting from 18 years old and the oldest patient is 85 years old. Understanding the minimum age and maximum age aids us in understanding the lower and upper boundary of the age range represented in the dataset. It helps us determine the eligibility for certain treatments, detecting diseases among different types of groups and ensuring it complies with legal regulations for healthcare services for patients. The mean Age of patients is 51 which shows the average age of patients. From this we are able to recognize valuable demographic profiling of patients which helps target the age of patients.
#
# For the variable Billing amount in USD, it shows that the maximum amount billed to a patient is 49995 USD and the minimum 1000 USD while the mean of billing amount is 25516 USD. The maximum amount helps us understand the upper limit of the financial burden associated with healthcare services. This insight is essential in understanding the gauge of potential medical treatment costs which are exceptionally high and can provide financial assistance for patients. Minimum is also similar and also helps understand the baseline cost of healthcare services. The mean billed amount shows the average expenses for a patient to receive healthcare services. From the analyzed data we can identify the financial impact it has on a patient and possibly reevaluate charging expenses to a more affordable price.

# %% [markdown]
# **RESULTS AND DISCUSSIONS**

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=20, kde=True, color = '#33D7FF', edgecolor='black')
plt.title('Age Distribution', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.legend(['Age'], fontsize=12)
plt.show()

# %% [markdown]
# The figure above shows a histogram of "Age Distribution" plot. From this plot we are able to visualize that

# %%
colors = ['skyblue', 'lightcoral', 'lightgreen', 'orange', 'lightpink', 'gold', 'lightblue']

plt.figure(figsize=(10, 10))
plt.pie(medical_condition_counts, labels=medical_condition_counts.index, autopct='%1.1f%%', startangle=140, colors=colors, shadow=True)
plt.title('Medical Condition Analysis', fontsize=16)
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.barplot(x=insurance_provider_counts.values, y=insurance_provider_counts.index, palette='Set2')
plt.title('Insurance Provider Analysis')
plt.xlabel('Frequency')
plt.ylabel('Insurance Provider')
plt.show()
# Out:
# <ipython-input-35-c6aa77a6f38c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=insurance_provider_counts.values, y=insurance_provider_counts.index, palette='Set2')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Insurance Provider', data=df, palette='Paired', order=df['Insurance Provider'].value_counts().index)
plt.title('Insurance Provider Analysis')
plt.xlabel('Insurance Provider')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-40-52acc94e8b05>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Insurance Provider', data=df, palette='Paired', order=df['Insurance Provider'].value_counts().index)

# %%
custom_palette = ['#FF33A2', '#9933FF', '#3380FF']
plt.figure(figsize=(10, 6))
sns.barplot(x=admission_type_counts.index, y=admission_type_counts.values, palette=custom_palette)
plt.title('Admission Type Comparison', fontsize=16)
plt.xlabel('Admission Type', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.show()
# Out:
# <ipython-input-72-18b335625075>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=admission_type_counts.index, y=admission_type_counts.values, palette=custom_palette)

# %%
plt.figure(figsize=(12, 8))
plt.fill_between(admissions_by_year.index, admissions_by_year.values, color='red', alpha=0.3)
plt.plot(admissions_by_year.index, admissions_by_year.values, marker='o', color='red', linewidth=2)
plt.title('Admissions by Year', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Admissions', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='Medication', inner='quartile', color ='#178330')
plt.title('Medication Distribution')
plt.xlabel('Medication')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x='Test Results', y=df.index, estimator=lambda x: len(x) / len(df) * 100, palette='rainbow')
plt.title('Test Results Distribution', fontsize=16)
plt.xlabel('Test Results', fontsize=14)
plt.ylabel('Percentage', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-91-948583d95644>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Test Results', y=df.index, estimator=lambda x: len(x) / len(df) * 100, palette='rainbow')

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='inferno')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# **CONCLUSION**

# %% [markdown]
# In conclusion,
