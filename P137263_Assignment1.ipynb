# %% [markdown]
# <a href="https://colab.research.google.com/github/DianaKahar/Data_management/blob/main/P137263_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ASSIGNMENT 1**

# %%
# !git config --global user.name "DianaKahar"
# !git config --global user.email "dianabdkahar@gmail.com"

# %%
token = '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'
username = 'DianaKahar'
repo = 'Data_Management'

# %%
# !git clone https://{token}@github.com/{username}//{repo}
# Out:
# Cloning into 'Data_Management'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 42 (delta 9), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (42/42), 1.49 MiB | 4.57 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %cd {repo}
# Out:
# /content/Data_Management

# %%
# %ls
# Out:
# healthcare_dataset.csv  P137263_Assignment1.ipynb  README.md

# %%
# !pwd
# Out:
# /content/Data_Management

# %%
# !git add .

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/Data_Management/.git/

# %%
# !git add P137263_Assignment1.ipynb
# !git commit -m 'commit message'
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %% [markdown]
# # **STQD6324 DATA MANAGEMENT**

# %% [markdown]
# **INTRODUCTION**

# %% [markdown]
# Healthcare is one of the major industries of progress and innovation, improving on all aspects like patient care, operational efficiency and advancing medical research. The collection and analysis of data, also efficient management plays a vital role in enhancing and transforming healthcare outcomes.
#
# Enormous amounts of data is generated daily by healthcare institutions, from medical imaging, genomic sequence, EHR (encompassing electronic health records), administration records and many more. The vast collection of data helps analyze valuable insights into a patient's demographic, disease widespread, treatment productiveness and resource utilization. Data management strategies and analytic techniques enable an organization to utilize the full potential of data collected.
#
# Healthcare data management requires the collection, storing, organizing and analyzing various datasets to assist in clinical decision making, optimization or operations and strategic planning. Healthcare providers are able to extract important insight from raw data which enables them to deliver specialized patient care, pinpoint high risk populations and  streamline healthcare workflows with the utilization of advanced analytics like machine learning algorithms and artificial intelligence tools.
#
# In addition, data management institutes are able to centralize the data that helps  practice collaborations, sharing knowledge among researchers, healthcare professionals and policymakers which accelerates scientific discoveries and enhances healthcare services and outcomes. The data collected from historical patient data aids healthcare providers to recognize patterns, predict disease progression and intervene early to prevent adverse outcomes. Real time data analytics assist healthcare professionals in personalizing treatments plans for patients needs, monitor patient responses which leads to a better patient quality care.
#
# For assignment 1, with the healthcare dataset required several analyses will be performed to gain insight and understand some underlying patterns.
#
# 1. Statistical summary for age and billing amount and determining the distribution of catagorical variable like blood type, gender and medical condition.

# %% [markdown]
# **DATASET INFORMATION**

# %% [markdown]
# For this assignment, the healthcare dataset was obtained from Kaggle.com, titled "Healthcare Dataset". The dataset contains 15 variables/columns which provides specific information on the patient, their admission and healthcare service provided.
#
# 1. Name: Patients name.
# 2. Age: Patients age.
# 3. Gender: "Male" or "Female."
# 4. Blood Type: The patient's blood type. (A, B, AB, O / POSITIVE OR NEGATIVE).
# 5. Medical Condition: Primary medical condition.
# 6. Date of Admission: Patient admission date.
# 7. Doctor: Doctors name for patient.
# 8. Hospital: Name of healthcare location.
# 9. Insurance Provider: Patient's insurance provider
# 10. Billing Amount: Billed expenses (USD).
# 11. Room Number: Room number at hospital.
# 12. Admission Type: Specifies the type of admission ("Emergency," "Elective," or "Urgent,").
# 13. Discharge Date: Discharged date.
# 14. Medication: Medication prescribed.
# 15. Test Results: Results of a medical test ("Normal," "Abnormal," or "Inconclusive,").

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Data_Management/healthcare_dataset.csv")
df.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# ...

# %% [markdown]
# **DATA CLEANING AND EXPLORATION**

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
summary_stats = df[['Age', 'Billing Amount']].describe()
print(summary_stats)
# Out:
#                 Age  Billing Amount
# count  10000.000000    10000.000000
# mean      51.452200    25516.806778
# std       19.588974    14067.292709
# min       18.000000     1000.180837
# 25%       35.000000    13506.523967
# 50%       52.000000    25258.112566
# 75%       68.000000    37733.913727
# max       85.000000    49995.902283

# %% [markdown]
# From the dataframe the summary stats were calculated for the variables 'Age' and 'Billing amount' only to understand the mean, std, min and max for patients within the healthcare dataset. From the variable 'Age' we are able to see that the minimum age of a patient is starting from 18 years old and the oldest patient is 85 years old. Understanding the minimum age and maximum age aids us in understanding the lower and upper boundary of the age range represented in the dataset. It helps us determine the eligibility for certain treatments, detecting diseases among different types of groups and ensuring it complies with legal regulations for healthcare services for patients. The mean Age of patients is 51 which shows the average age of patients. From this we are able to recognize valuable demographic profiling of patients which helps target the age of patients.
#
# For the variable Billing amount in USD, it shows that the maximum amount billed to a patient is 49995 USD and the minimum 1000 USD while the mean of billing amount is 25516 USD. The maximum amount helps us understand the upper limit of the financial burden associated with healthcare services. This insight is essential in understanding the gauge of potential medical treatment costs which are exceptionally high and can provide financial assistance for patients. Minimum is also similar and also helps understand the baseline cost of healthcare services. The mean billed amount shows the average expenses for a patient to receive healthcare services. From the analyzed data we can identify the financial impact it has on a patient and possibly reevaluate charging expenses to a more affordable price.

# %% [markdown]
# **RESULTS AND DISCUSSIONS**

# %% [markdown]
# **AGE DISTRIBUTION**

# %%
df.groupby('Age')['Age'].sum()
# Out:
# Age
# 18     2952
# 19     2508
# 20     3380
# 21     3213
# 22     2706
#       ...
# 81    12879
# 82    12054
# 83    10873
# 84    11172
# 85    10455
# Name: Age, Length: 68, dtype: int64

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=20, kde=True, color = '#33D7FF', edgecolor='black')
plt.title('Age Distribution', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.legend(['Age'], fontsize=12)
plt.show()

# %% [markdown]
# The figure above shows a histogram of "Age Distribution" plot ranging from the age 18 to 85 years old. From this plot we are able to visualize that the highest frequency of patients occurs within the range 35 to 37 and 76 to 78 years old. These age groups may represent stages in life where individuals are more susceptible to health issues or require medical attention due to a variety of reasons such as stress from work, family responsibilities, and lifestyle conditions. The older age group is commonly associated with chronic conditions like arthritis and diabetes. While the lowest frequency is between the ages 31 to 33 years old which suggests fewer patients admitted to hospitals. Individuals from this age group are less prone to medical issues and some may delay in seeking medical issues due to being more focused on other priorities. This histogram highlights the age ranges of patients that is valuable in understanding the demographics of patient population and recognizing trends and patterns in the healthcare system.

# %% [markdown]
# **MEDICAL CONDITION ANALYSIS**

# %%
colors = ['skyblue', 'lightcoral', 'lightgreen', 'orange', 'lightpink', 'gold', 'lightblue']
medical_condition_counts = df['Medical Condition'].value_counts()
plt.figure(figsize=(10, 10))
plt.pie(medical_condition_counts, labels=medical_condition_counts.index, autopct='%1.1f%%', startangle=140, colors=colors, shadow=True)
plt.title('Medical Condition Analysis', fontsize=16)
plt.axis('equal')
plt.show()

# %% [markdown]
# The pie chart visualizes the distribution of different medical conditions among patients, only the top 6 commonly diagnosed diseases were included, which comprises of diabetes, obesity, arthritis, hypertension, cancer and asthma. Each slice of the pie represents a specific medical condition and the size indicates the portion of patients affected by the disease. From this pie chart we can evaluate that Asthma comprises the largest portion of the pie at 17.1% which indicates the highest portion of patients are affiliated with asthma due to air pollution of smoking habits, while diabetes has the smallest piece of pie that accounts for 16.2% of patients diagnosed with diabetes. Through this pie chart we are able to identify the distribution of medical conditions among patients. Conditions like hypertension and diabetes are commonly chronic conditions which can affect a significant portion of the population. Lifestyle factors, physical activities and diet can reduce disease like obesity and diabetes. Conditions such as arthritis and hypertension are more commonly found among the older population. This information enables the healthcare institutions in allocating resources, developing treatment plans and personalizing specific needs of patients based on their medical conditions.

# %% [markdown]
# **INSURANCE PROVIDER ANALYSIS**

# %%
insurance_provider_counts = df['Insurance Provider'].value_counts()
plt.figure(figsize=(10, 8))
sns.barplot(x=insurance_provider_counts.values, y=insurance_provider_counts.index, palette='Set2')
plt.title('Insurance Provider Analysis')
plt.xlabel('Frequency')
plt.ylabel('Insurance Provider')
plt.show()
# Out:
# <ipython-input-19-9ae2688059d2>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=insurance_provider_counts.values, y=insurance_provider_counts.index, palette='Set2')

# %%
print(insurance_provider_counts)
# Out:
# Insurance Provider
# Cigna               2040
# Blue Cross          2032
# Aetna               2025
# UnitedHealthcare    1978
# Medicare            1925
# Name: count, dtype: int64

# %% [markdown]
# The barplot of insurance provider analysis exhibits the distribution of patients admitted to hospitals based on their insurance coverage (company name) and the frequencies. The most commonly used insurance provider is ‘Cigna’ with 2040 numbers of patients. This may be due ‘Cigna's extensive network of health providers and facilities, offering patients a wider range of options for medical services. ‘Cigna’ may also offer deals for company or employee insurance that have a better benefits package and at an affordable rate. Second commonly used insurance among patients is ‘Blue Cross’ with a frequency of 2032. ‘Blue cross’ has a reputation for providing comprehensive coverage and access to a broad range of healthcare professionals and institutions. ‘Blue Cross’ also has a long partnership with healthcare providers and facilities, offering patients with access to a wide range of medical services. ‘Aetna’ comes in at 3rd with a frequency of 2025 among patients. The possible reasons may include a competitive insurance plan with flexible coverage options specializing in health management services. ‘Aetna’ also concentrates on its quality of services, innovative care delivery models and wellness initiatives for its customers. Coming in at 4th place, ‘UnitedHealthcare’ with the frequency of 1978 among patients. This insurance provider may hold a diverse portfolio of insurance products which includes employer sponsored plans, government programs and individual policies. Lastly, ‘Medicare’ with a frequency of 1925 which is the lowest among the other insurance providers. The reasons for this is maybe due to the eligibility criteria which primarily serves older aged people from the age 65 and older who may require frequent medical service due to age related conditions and chronic illness. ‘Medicare’ is also known as a government-sponsored program with a rather long history of medical coverage to millions of people. Overall, the barplot offers insight into the distribution of insurance coverage among patients reflecting on their demographic, preference and medical needs.

# %% [markdown]
# **ADMISSION COMPARISSON**

# %%
admission_type_counts = df['Admission Type'].value_counts()
custom_palette = ['#FF33A2', '#9933FF', '#3380FF']
plt.figure(figsize=(10, 6))
sns.barplot(x=admission_type_counts.index, y=admission_type_counts.values, palette=custom_palette)
plt.title('Admission Type Comparison', fontsize=16)
plt.xlabel('Admission Type', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.show()
# Out:
# <ipython-input-21-cdfdbe57a6a6>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=admission_type_counts.index, y=admission_type_counts.values, palette=custom_palette)

# %%
print(admission_type_counts)
# Out:
# Admission Type
# Urgent       3391
# Emergency    3367
# Elective     3242
# Name: count, dtype: int64

# %% [markdown]
# The figure illustrates a barplot comparing types of admission that provides insight into the distribution of patients admitted into hospitals based on the circumstance and urgency of their situation.  Urgent admission has the frequency with a of 3391 patients. Reasons for this high frequency may include patients with acute medical conditions which require immediate medical attention. Physician patient referrals also are included in urgent admission based on clinical assessments. Other reasons may be due to patients requiring urgent evaluation and treatment but are not life threatening. Emergency admission closely followed with a total count of 3367 patients. Patients admitted under emergency often present life threatening injuries, acute illness, or medical emergencies which require immediate intervention to stabilize their conditions. Patients admitted under emergency by EMS transported by ambulance due to their severe conditions which are time sensitive and need to administer surgery or resuscitations to help the patients. Lastly is elective admissions with the frequency of 3242 patients. This admission is commonly a scheduled procedure like patients with planned surgeries, non urgent medical surgeries or conditions and diagnostic tests. Some patients may include chronic medical conditions that require elective procedures of treatments aimed at managing symptoms , preventing disease progression and improving patients quality of life. This bar plot provides knowledgeable insight on types of hospital admissions.

# %% [markdown]
# **TEMPORAL ANALYSIS**

# %%
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'])
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'])

df['Year of Admission'] = df['Date of Admission'].dt.year
admissions_by_year = df['Year of Admission'].value_counts().sort_index()

plt.figure(figsize=(12, 8))
plt.fill_between(admissions_by_year.index, admissions_by_year.values, color='red', alpha=0.3)
plt.plot(admissions_by_year.index, admissions_by_year.values, marker='o', color='red', linewidth=2)
plt.title('Admissions by Year', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Admissions', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
print(admissions_by_year)
# Out:
# Year of Admission
# 2018     303
# 2019    1973
# 2020    2044
# 2021    2063
# 2022    2001
# 2023    1616
# Name: count, dtype: int64

# %% [markdown]
# This plot illustrates the temporal analysis of the date of admission and discharge date across the years (2018-2023) providing insight into trends and patterns of hospital admissions and discharges over time. From the data we can observe fluctuations in the number of admissions in 2019, a significant increase from 2018 and reaching its peak in 2021. However, there is a slight decline in admission in 2023 compared to the previous years. Temporal analysis provides insight into trends of admission, which is valuable for healthcare institutes and policymakers.
# Factors to be considered that influence the trends, peaks n decline are changes in population demographics; population growth, shift in disease prevalence and aging population controls the demand for medical services hence impacts the number of hospital admissions. Understanding the patterns can help medical institutes anticipate and allocate resources effectively, plan workforce and adapt to patients' needs and demands.

# %% [markdown]
# **CORRELATION ANALYSIS**

# %%
selected_columns = ['Age', 'Billing Amount', 'Year of Admission']
numeric_df = df[selected_columns].copy()
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='inferno')
plt.title('Correlation Matrix')
plt.show()

# %%
print(correlation_matrix)
# Out:
#                         Age  Billing Amount  Year of Admission
# Age                1.000000       -0.009483          -0.012592
# Billing Amount    -0.009483        1.000000          -0.000149
# Year of Admission -0.012592       -0.000149           1.000000

# %% [markdown]
# The heatmap plot of the correlation matrix provides a visual representation of the relationships between the variables 'Age', 'Billing Amount', and 'Year of Admission' in our dataset. Each cell in the heatmap represents the correlation coefficient between two variables, ranging from -1 to 1. The correlation between Age and Billing amount is a very weak negative correlation (-0.009). It suggests there is almost no linear relationship between a patient's age and the amount billed for their medical services. For the correlation coefficient between Age and Year of Admission also has a very weak negative correlation (-0.013), it indicates that there isn't a linear relationship between patients age and the year in which they were admitted to the medical institute. Lasty, the correlation coefficient between Billing amount and Years of Admission is an extremely weak negative correlation (-0.00015) which also suggests no linear relationship between these two variables. Understanding these correlations can help identify the potential patterns and trends in the data. The heatmap plot was able to provide insight between different variables in aiding further analysis and decision making process.

# %% [markdown]
# **CONCLUSION**

# %% [markdown]
# Based on all the insight collected from the analysis of healthcare data, various conclusions can be drawn. Age distribution of patients admitted gave insight on the highest and lowest age range of admitted patients which suggests there may be a specific age demographic that are prone to seek medical services. For medical conditions there are 6 top commonly diagnosed diseases which includes asthma, diabetes, obesity, hypertension, cancer and arthritis. The most common insurance providers affiliated with patients are with ‘Cigna’, followed by ‘Blue Cross’, ‘Aetna’, ‘UnitedHealthcare’ and lastly ‘Medicare’. The distribution shows the diverse range of insurance providers utilized by patients. The analysis of admission types uncovers that patients are admitted under various circumstances including urgent, emergency and elective cases. This exhibits the importance of prompt and efficient medical delivery for different patient needs. The temporal analysis reveals over the years from 2018 to 2023, the number of hospital admission fluctuates with the highest observed in 2012 and the lowest in 2018. The analysis may be influenced by factors like population demographics, medical policies and disease prevalence. The correlation analysis matrix indicates a very weak relationship between age, billing amount and years of admission which suggest that the variables may not have significant predictive power in determining medical outcomes or costs. In conclusion, the analysis executed from the healthcare data provided knowledgeable insight into patient demographics, medical conditions, insurance coverage, admission patterns, temporal trends and variable relationships. These findings are valuable to healthcare professionals, policymakers, stakeholders in making data driven decisions to improve medical delivery, enhance patient outcome and optimize resource allocation.
